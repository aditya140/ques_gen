# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya140/ques_gen/blob/master/Nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf ques_gen
# !git clone https://github.com/aditya140/ques_gen.git
# !nvidia-smi
# Out:
# Cloning into 'ques_gen'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 334 (delta 0), reused 0 (delta 0), pack-reused 331
# Receiving objects: 100% (334/334), 110.62 MiB | 26.57 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
# Mon Dec  9 03:41:53 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.33.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# ...

# %%
cd ques_gen/
# Out:
# /content/ques_gen

# %%
# !pip install -r req.txt
# !bash setup.sh
# Out:
# ...
#      |████████████████████████████████| 102kB 4.6MB/s
# ...
#      |████████████████████████████████| 184kB 35.9MB/s
# ...
#      |████████████████████████████████| 6.2MB 43.6MB/s
# ...
#      |████████████████████████████████| 8.1MB 31.7MB/s
# ...
#      |████████████████████████████████| 102kB 12.2MB/s
# ...
#      |████████████████████████████████| 153kB 39.7MB/s
# ...
#      |████████████████████████████████| 3.7MB 43.6MB/s
# ...
#      |████████████████████████████████| 16.2MB 15.8MB/s
# ...
#      |████████████████████████████████| 112kB 46.2MB/s
# ...
#      |████████████████████████████████| 163kB 46.9MB/s
# ...
#      |████████████████████████████████| 430kB 42.4MB/s
# ...
#      |████████████████████████████████| 2.1MB 44.6MB/s
# ...
#      |████████████████████████████████| 2.1MB 42.0MB/s
# ...
#      |████████████████████████████████| 450kB 48.9MB/s
# ...
#      |████████████████████████████████| 686kB 40.9MB/s
# ...
#      |████████████████████████████████| 501kB 43.7MB/s
# ...
#      |████████████████████████████████| 552kB 53.2MB/s
# ...

# %%
import os

def restart_runtime():
  os.kill(os.getpid(), 9)

# %%
# !python train.py
# Out:
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# Load Failure :  0
# Load Failure :  0
# Load Failure :  5945
# Load Failure :  43498
# Load Failure :  0
# Dataframe size: (84792, 4)
# Loading pretrained embeddings
# .vector_cache/glove.42B.300d.zip: 1.88GB [14:34, 2.15MB/s]
# tcmalloc: large alloc 2300993536 bytes == 0x166f6000 @  0x7f8cbe7e8b6b 0x7f8cbe808379 0x7f8c6b6a42ea 0x7f8c6b6a5d9a 0x7f8c6d8b7c1b 0x7f8c6da9c6fb 0x7f8c6d8b84ed 0x7f8c6d8bd345 0x7f8c6dbe2323 0x7f8cb390b294 0x7f8cb383128e 0x50abc5 0x50c549 0x5081d5 0x50a020 0x50aa1d 0x50d320 0x5081d5 0x5095d2 0x5951c1 0x5a04ce 0x50d8f5 0x5081d5 0x5095d2 0x5951c1 0x54a11f 0x551761 0x5a508c 0x5f0adc 0x5a04ce 0x50d8f5
# ...

# %%
# !python eval_metrics.py
